# %%
from PIL import Image
import numpy as np
from skimage import transform
import os
import shutil
import tensorflow as tf
from tensorflow import keras

def load(filename):
    
    np_image = Image.open(filename)
    np_image = np.array(np_image).astype('float32')/255
    np_image = transform.resize(np_image, (128,128, 3))
    np_image = np.expand_dims(np_image, axis=0)
    return np_image


model_path = r"C:\Users\ee527\Dementia_Vision_beta\model\test.h5"
directory_name = r"D:\test_system\in"


model = tf.keras.models.load_model(model_path)


tolerance = 0

for file_name in os.listdir(directory_name):
    
    base = file_name.split(".")[0]
    
    image_path = directory_name + "/" + file_name  
        
    image = load(image_path)
    
    predict = model.predict(image)   
         
        
    if predict < 0.5:
        
        print(f"detect absence at {base}")
        print(" ")
        
        #print("start tolerance mechanism")
        tolerance+=1
      
    else:
        print(f"detect person at {base}")
        print(" ")
        tolerance = 0
       
   

    if tolerance == 5:
        print("person leave!!")
        print(" ")
# Out:
# detect absence at 20210825_t021020
#
# detect absence at 20210825_t021022
#
# detect absence at 20210825_t021024
#
# detect absence at 20210825_t021026
#
# detect absence at 20210825_t021028
#
# person leave!!
#
# detect absence at 20210825_t021030
#
# detect absence at 20210825_t021032
#
# detect absence at 20210825_t021034
#
# detect absence at 20210825_t021036
#
# detect absence at 20210825_t021038
#
# detect absence at 20210825_t021040
#
# detect absence at 20210825_t021042
#
# detect absence at 20210825_t021044
#
# detect absence at 20210825_t021046
#
# detect absence at 20210825_t021048
#
# detect absence at 20210825_t021050
#
# detect person at 20210825_t021052
#
# detect person at 20210825_t021054
#
# detect person at 20210825_t021056
#
# detect person at 20210825_t021058
#
# detect person at 20210825_t021100
#
# detect person at 20210825_t021102
#
# detect person at 20210825_t021104
#
# detect person at 20210825_t021106
#
# detect person at 20210825_t021108
#
# ...
