# %% [markdown]
# ## test

# %%
import requests

def lineNotifyMessage(token, msg):

    headers = {
        "Authorization": "Bearer " + token, 
        "Content-Type" : "application/x-www-form-urlencoded"
    }

    payload = {'message': msg }
    r = requests.post("https://notify-api.line.me/api/notify", headers = headers, params = payload)
    return r.status_code


if __name__ == "__main__":
    
    token = 'EUCg8ckDngkPLHqKJ81pgCf5JJs1g92L6lAHk4kEnMf' 
    message = '笨妹'
    lineNotifyMessage(token, message)

# %% [markdown]
# ## start

# %%
from PIL import Image
import numpy as np
from skimage import transform
import os
import shutil
import tensorflow as tf
from tensorflow import keras
import requests
import cv2
import time
from pathlib import Path

def lineNotifyMessage(token, msg, idir):

    headers = {
        "Authorization": "Bearer " + token, 
    }

    payload = {'message': msg }
    images = {"imageFile": open(str(idir),"rb")}
    r = requests.post("https://notify-api.line.me/api/notify", headers = headers, params = payload, files = images)
    return r.status_code





def load(filename):
    
    np_image = Image.open(filename)
    np_image = np.array(np_image).astype('float32')/255
    np_image = transform.resize(np_image, (128,128, 3))
    np_image = np.expand_dims(np_image, axis=0)
    return np_image



model_path = r"C:/Users/ee527/Dementia_Vision_beta/model/test.h5"
directory_name = r"D:/Dementia_Data_Preprocessing/testing_data/all"

token = 'EUCg8ckDngkPLHqKJ81pgCf5JJs1g92L6lAHk4kEnMf'  #  EUCg8ckDngkPLHqKJ81pgCf5JJs1g92L6lAHk4kEnMf

message = 'leaving bed detect!'
    

model = tf.keras.models.load_model(model_path)
print("start predict")
num_count = 0
for file_name in os.listdir(directory_name):
    
    num_count = num_count+1
    
    image_path = Path(directory_name + "/" + file_name)
    
    
    image = load(image_path)
    
    predict = model.predict(image)   
   
    
    if predict < 0.5: 
    
        print(message)
        print(image_path)
        lineNotifyMessage(token, message, image_path)
        
        
    
  
        
      
                
    
print("total number:", num_count)
# Out:
# start predict
# leaving bed detect!
# D:\Dementia_Data_Preprocessing\testing_data\all\20210825_t000000.jpg
# leaving bed detect!
# D:\Dementia_Data_Preprocessing\testing_data\all\20210825_t000002.jpg
# leaving bed detect!
# D:\Dementia_Data_Preprocessing\testing_data\all\20210825_t000004.jpg
# leaving bed detect!
# D:\Dementia_Data_Preprocessing\testing_data\all\20210825_t000006.jpg
# leaving bed detect!
# D:\Dementia_Data_Preprocessing\testing_data\all\20210825_t000008.jpg
# leaving bed detect!
# D:\Dementia_Data_Preprocessing\testing_data\all\20210825_t000010.jpg
# leaving bed detect!
# D:\Dementia_Data_Preprocessing\testing_data\all\20210825_t000012.jpg
# leaving bed detect!
# D:\Dementia_Data_Preprocessing\testing_data\all\20210825_t000014.jpg
# leaving bed detect!
# D:\Dementia_Data_Preprocessing\testing_data\all\20210825_t000016.jpg
# ---------------------------------------------------------------------------
# ...
