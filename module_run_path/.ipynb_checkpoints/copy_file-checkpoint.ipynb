# %%
import shutil
import os

path1 = r"D:\Dementia_Data_Preprocessing\testing_data\20211023\block5conv2\bbox"
source = r"D:\Dementia_Data_Preprocessing\main\out_image"
des = r"D:\Dementia_Data_Preprocessing\testing_data\20211023\original"

for filename in os.listdir(path1):
    
    print(filename)
    
    
    dest = shutil.copy(source + "\\"+filename, des+ "\\"+filename)
# Out:
# 20211023_t002508.jpg
# 20211023_t002512.jpg
# 20211023_t002550.jpg
# 20211023_t002600.jpg
# 20211023_t002602.jpg
# 20211023_t002604.jpg
# 20211023_t002606.jpg
# 20211023_t002608.jpg
# 20211023_t002610.jpg
# 20211023_t002614.jpg
# 20211023_t002616.jpg
# 20211023_t002618.jpg
# 20211023_t002620.jpg
# 20211023_t002622.jpg
# 20211023_t002624.jpg
# 20211023_t002626.jpg
# 20211023_t002628.jpg
# 20211023_t002630.jpg
# 20211023_t002632.jpg
# 20211023_t002634.jpg
# 20211023_t002636.jpg
# 20211023_t002638.jpg
# 20211023_t002640.jpg
# 20211023_t002642.jpg
# 20211023_t002644.jpg
# 20211023_t002646.jpg
# 20211023_t002648.jpg
# 20211023_t002650.jpg
# 20211023_t002652.jpg
# 20211023_t002654.jpg
# 20211023_t002656.jpg
# 20211023_t002658.jpg
# 20211023_t002700.jpg
# 20211023_t002702.jpg
# 20211023_t002704.jpg
# 20211023_t002706.jpg
# 20211023_t002708.jpg
# 20211023_t002710.jpg
# 20211023_t002712.jpg
# 20211023_t002714.jpg
# 20211023_t002716.jpg
# 20211023_t002718.jpg
# 20211023_t002720.jpg
# ...
