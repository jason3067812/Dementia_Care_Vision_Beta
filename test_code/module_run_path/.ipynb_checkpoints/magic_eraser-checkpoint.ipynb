# %% [markdown]
# ## magic eraser algorithm

# %%
import cv2

img = cv2.imread(r"D:\Dementia_Data_Preprocessing\testing_data\20210825\all\20210825_t010012.jpg",0)
threshold = 15


img_copy = img
shape = img.shape
ymax = shape[0]
xmax = shape[1]

for i in range(ymax):   
    for j in range(xmax):
        count = 0
        adjacent_list = []  
        
        now_pixel = int(img[i][j])
                
        if j-1 >= 0:
            count+=1
            up_pixel = int(img[i][j-1])
            
            if abs(up_pixel - now_pixel) > threshold:               
                adjacent_list.append(up_pixel)            
        
     
        if j+1 < xmax:
            count+=1
            down_pixel = int(img[i][j+1])
            
            if abs(down_pixel - now_pixel) > threshold:               
                adjacent_list.append(down_pixel)   
                        
       
        if i-1 >= 0:
            count+=1
            left_pixel = int(img[i-1][j])
            
            if abs(left_pixel - now_pixel) > threshold:               
                adjacent_list.append(left_pixel) 
            
      
        if i+1 < ymax:
            count+=1
            right_pixel = int(img[i+1][j])
            
            if abs(right_pixel - now_pixel) > threshold:  
                adjacent_list.append(right_pixel)

        if count == len(adjacent_list):
            
            average = int(sum(adjacent_list)/count)          
            img_copy[i][j] = average
            
            print(f"點{(i,j)}:{now_pixel} => {average}")
       
        
cv2.imwrite("D:/a.jpg", img_copy)
# Out:
# 點(0, 1):142 => 123
# 點(1, 2):151 => 125
# 點(2, 20):121 => 140
# 點(3, 0):144 => 126
# 點(3, 25):127 => 145
# 點(6, 5):149 => 127
# 點(12, 0):123 => 143
# 點(12, 9):154 => 133
# 點(14, 20):123 => 144
# 點(14, 31):125 => 142
# 點(15, 28):161 => 133
# 點(16, 1):155 => 134
# 點(18, 0):253 => 130
# 點(18, 16):100 => 133
# 點(18, 18):100 => 137
# 點(18, 20):108 => 144
# 點(18, 22):101 => 135
# 點(18, 24):115 => 141
# 點(19, 15):152 => 130
# 點(19, 17):166 => 134
# 點(19, 21):171 => 139
# 點(19, 23):179 => 136
# 點(20, 4):124 => 144
# 點(22, 5):150 => 128
# True

# %% [markdown]
# ## check stdev

# %%
import numpy as np
import cv2

path = r"D:\test3_magic_eraser\20211023_t054904.jpg"
img = cv2.imread(path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cropped = img[0:16, 0:32]
crop2 = img[16:24, 0:32]

arr = np.array(cropped)
arr2 = arr.flatten()

arr_b = np.array(crop2)
arr_b2 = arr_b.flatten()

a = np.std(arr2, ddof=1)
b = np.std(arr_b2, ddof=1)

print("bed stdev:",a)
print("floor stdev:",b)

# %% [markdown]
# ## run path

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os


# 修改路徑
directory_name = r'D:\test6\b'
new_directory_name = r'D:\test6\c'
threshold = 15



for filename in os.listdir(directory_name):
    print("")
    print(filename)
    
    # 讀取原始影像灰度顏色
    img = cv2.imread(directory_name + "/" + filename,0)
        
    img_copy = img
    shape = img.shape
    ymax = shape[0]
    xmax = shape[1]

    for i in range(ymax):   
        for j in range(xmax):
            count = 0
            adjacent_list = []  

            now_pixel = int(img[i][j])

            if j-1 >= 0:
                count+=1
                up_pixel = int(img[i][j-1])

                if abs(up_pixel - now_pixel) > threshold:               
                    adjacent_list.append(up_pixel)            


            if j+1 < xmax:
                count+=1
                down_pixel = int(img[i][j+1])

                if abs(down_pixel - now_pixel) > threshold:               
                    adjacent_list.append(down_pixel)   


            if i-1 >= 0:
                count+=1
                left_pixel = int(img[i-1][j])

                if abs(left_pixel - now_pixel) > threshold:               
                    adjacent_list.append(left_pixel) 


            if i+1 < ymax:
                count+=1
                right_pixel = int(img[i+1][j])

                if abs(right_pixel - now_pixel) > threshold:  
                    adjacent_list.append(right_pixel)

            if count == len(adjacent_list):

                average = int(sum(adjacent_list)/count)          
                img_copy[i][j] = average

                print(f"點{(i,j)}:{now_pixel} => {average}")
                


    cv2.imwrite(new_directory_name + "/" + filename, img_copy)
print("finish")
# Out:
# 20211023_t055214.jpg
# 點(0, 19):96 => 71
# 點(1, 25):47 => 73
# 點(2, 22):61 => 92
# 點(3, 7):48 => 66
# 點(3, 18):88 => 65
# 點(3, 22):110 => 85
# 點(3, 30):155 => 119
# 點(4, 24):53 => 94
# 點(5, 12):96 => 68
# 點(5, 14):96 => 66
# 點(6, 26):108 => 76
# 點(6, 30):118 => 78
# 點(7, 27):55 => 86
# 點(8, 8):52 => 70
# 點(8, 14):50 => 77
# 點(8, 23):105 => 78
# 點(9, 4):93 => 59
# 點(10, 18):47 => 79
# 點(12, 7):48 => 66
# 點(19, 12):47 => 64
# 點(20, 30):94 => 65
#
# 20211023_t055216.jpg
# 點(0, 16):90 => 68
# 點(0, 25):51 => 79
# 點(0, 29):53 => 75
# 點(1, 26):51 => 77
# 點(2, 30):118 => 114
# 點(3, 29):130 => 115
# 點(3, 30):154 => 123
# 點(4, 22):98 => 74
# 點(4, 28):139 => 107
# 點(5, 17):106 => 79
# 點(5, 27):81 => 105
# 點(7, 13):100 => 70
# 點(7, 22):105 => 81
# 點(7, 31):122 => 90
# 點(8, 2):88 => 59
# 點(8, 7):51 => 77
# 點(9, 28):56 => 99
# 點(9, 31):112 => 85
# 點(12, 15):97 => 68
# 點(12, 26):86 => 63
# 點(18, 30):92 => 61
# 點(19, 31):96 => 60
# 點(20, 28):55 => 79
# 點(21, 17):48 => 70
# 點(22, 26):78 => 57
# 點(23, 28):80 => 58
#
# 20211023_t055218.jpg
# 點(0, 16):105 => 76
# 點(0, 21):77 => 103
# 點(0, 24):94 => 75
# 點(1, 5):85 => 58
# 點(1, 13):102 => 67
# 點(1, 28):58 => 91
# 點(1, 30):107 => 71
# 點(1, 31):51 => 86
# 點(2, 0):85 => 62
# 點(2, 16):112 => 80
# 點(3, 5):79 => 60
# 點(3, 13):102 => 72
# 點(3, 15):104 => 81
# 點(3, 29):133 => 112
# 點(4, 25):73 => 102
# 點(5, 20):65 => 104
# 點(5, 30):78 => 124
# 點(6, 4):93 => 63
# 點(6, 9):62 => 87
# 點(6, 12):104 => 83
# 點(6, 19):71 => 101
# 點(6, 21):68 => 104
# 點(6, 24):120 => 91
# 點(7, 3):93 => 59
# 點(8, 4):98 => 71
# 點(8, 22):111 => 90
# 點(9, 28):75 => 101
# 點(10, 0):95 => 61
# 點(10, 25):63 => 88
# 點(10, 31):125 => 80
# 點(11, 5):86 => 62
# 點(11, 28):57 => 79
# 點(12, 18):93 => 69
# 點(12, 23):55 => 81
# 點(13, 3):89 => 60
# 點(13, 15):95 => 72
# 點(15, 16):52 => 71
# 點(15, 29):97 => 62
# 點(15, 31):89 => 61
# 點(17, 1):86 => 60
# 點(18, 20):90 => 62
# 點(19, 4):52 => 75
# 點(19, 29):91 => 65
# 點(19, 31):106 => 70
# 點(20, 28):90 => 66
# 點(21, 25):95 => 60
# 點(21, 29):102 => 68
# 點(22, 8):88 => 62
# 點(23, 0):51 => 71
# 點(23, 13):81 => 56
# 點(23, 23):96 => 64
# 點(23, 28):53 => 84
# 點(23, 30):54 => 82
#
# 20211023_t055220.jpg
# 點(0, 20):75 => 112
# 點(0, 25):92 => 63
# 點(0, 31):65 => 83
# 點(1, 6):83 => 61
# 點(2, 23):116 => 91
# 點(2, 28):56 => 97
# 點(2, 30):108 => 105
# 點(3, 14):72 => 92
# 點(3, 20):117 => 83
# 點(4, 17):108 => 82
# 點(5, 20):67 => 92
# 點(6, 14):69 => 93
# 點(6, 22):118 => 91
# 點(6, 28):91 => 115
# 點(7, 20):126 => 84
# 點(8, 9):111 => 73
# 點(8, 20):66 => 91
# 點(10, 14):55 => 82
# 點(10, 15):98 => 75
# 點(10, 31):66 => 98
# 點(11, 21):93 => 62
# 點(21, 19):88 => 59
# 點(22, 31):63 => 90
# 點(23, 12):48 => 68
#
# 20211023_t055222.jpg
# 點(0, 7):51 => 68
# 點(2, 23):119 => 79
# 點(3, 14):97 => 64
# 點(3, 29):110 => 105
# 點(3, 30):157 => 117
# 點(4, 19):55 => 88
# 點(5, 26):106 => 82
# 點(5, 28):128 => 92
# 點(6, 3):86 => 57
# 點(6, 10):51 => 71
# 點(6, 22):57 => 92
# 點(6, 29):121 => 93
# 點(7, 27):77 => 104
# 點(7, 31):108 => 105
# 點(8, 9):108 => 70
# 點(8, 26):65 => 98
# 點(9, 4):91 => 61
# 點(9, 9):91 => 68
# 點(10, 5):97 => 60
# 點(10, 14):49 => 77
# 點(11, 30):92 => 70
# 點(13, 9):49 => 66
# 點(13, 22):48 => 71
# 點(21, 12):52 => 68
# 點(22, 3):86 => 59
# 點(22, 19):75 => 54
# 點(23, 4):93 => 58
#
# 20211023_t055224.jpg
# 點(0, 4):99 => 67
# 點(0, 18):88 => 110
# 點(0, 24):104 => 73
# 點(0, 27):85 => 64
# 點(0, 31):86 => 66
# 點(1, 7):47 => 67
# 點(2, 30):102 => 102
# 點(3, 0):47 => 68
# 點(3, 14):105 => 72
# 點(4, 7):48 => 69
# 點(4, 28):73 => 126
# 點(5, 24):120 => 87
# 點(6, 19):112 => 82
# 點(6, 26):67 => 98
# 點(6, 30):51 => 104
# 點(8, 3):84 => 60
# 點(8, 10):91 => 66
# 點(8, 15):91 => 59
# 點(8, 18):101 => 64
# 點(9, 19):98 => 67
# 點(9, 31):56 => 95
# 點(10, 22):49 => 75
# 點(11, 25):50 => 74
# 點(13, 28):80 => 55
# 點(14, 11):49 => 68
# 點(19, 29):83 => 62
# 點(22, 31):76 => 55
#
# 20211023_t055226.jpg
# 點(1, 15):49 => 73
# 點(1, 22):111 => 83
# 點(2, 1):80 => 57
# 點(2, 17):108 => 68
# 點(2, 22):61 => 93
# 點(2, 30):104 => 97
# 點(3, 10):85 => 60
# 點(3, 16):95 => 70
# 點(3, 20):104 => 69
# 點(3, 30):157 => 113
# 點(3, 31):132 => 98
# 點(5, 29):73 => 103
# 點(7, 8):93 => 67
# 點(7, 28):125 => 93
# 點(8, 5):93 => 65
# 點(8, 21):106 => 71
# 點(9, 22):94 => 69
# 點(9, 27):110 => 78
# 點(10, 31):65 => 98
# 點(11, 27):102 => 74
# 點(13, 17):51 => 73
# 點(14, 22):85 => 57
# 點(20, 12):46 => 69
# 點(20, 24):51 => 69
# 點(20, 29):81 => 62
#
# 20211023_t055228.jpg
# 點(0, 21):69 => 107
# 點(0, 23):62 => 96
# 點(0, 31):53 => 70
# 點(1, 22):81 => 95
# 點(2, 22):56 => 95
# 點(2, 25):112 => 78
# 點(3, 16):71 => 100
# 點(3, 19):78 => 108
# 點(3, 30):155 => 119
# 點(4, 22):119 => 85
# 點(5, 31):148 => 101
# 點(7, 7):95 => 66
# 點(7, 26):66 => 91
# 點(7, 31):125 => 100
# 點(8, 17):50 => 84
# 點(9, 6):81 => 60
# 點(9, 20):115 => 87
# 點(9, 24):64 => 92
# 點(9, 29):65 => 101
# 點(9, 30):117 => 81
# 點(11, 4):86 => 59
# 點(11, 25):107 => 70
# 點(11, 31):96 => 67
# 點(14, 9):46 => 67
# 點(16, 30):116 => 57
# 點(20, 24):90 => 59
# 點(21, 29):94 => 68
# 點(21, 31):54 => 73
# 點(23, 7):88 => 61
#
# 20211023_t055230.jpg
# 點(0, 30):108 => 64
# 點(1, 14):91 => 60
# 點(1, 23):93 => 78
# 點(2, 11):52 => 73
# 點(2, 18):106 => 88
# 點(2, 19):124 => 95
# 點(2, 23):110 => 82
# 點(2, 25):100 => 67
# 點(2, 31):93 => 123
# 點(3, 26):121 => 83
# 點(3, 28):145 => 92
# 點(4, 18):110 => 70
# 點(4, 24):69 => 96
# 點(4, 30):130 => 123
# 點(5, 21):55 => 91
# 點(5, 23):71 => 105
# 點(6, 8):52 => 69
# 點(6, 15):60 => 92
# 點(6, 22):73 => 117
# 點(6, 24):70 => 100
# 點(6, 26):149 => 100
# 點(7, 21):56 => 103
# 點(7, 22):139 => 90
# 點(7, 25):71 => 98
# 點(8, 14):91 => 61
# 點(8, 26):126 => 101
# 點(8, 30):146 => 94
# 點(9, 3):96 => 56
# 點(9, 15):99 => 58
# 點(9, 17):81 => 57
# 點(9, 22):50 => 81
# 點(9, 23):105 => 71
# 點(9, 31):151 => 82
# 點(10, 23):50 => 75
# 點(10, 26):52 => 80
# 點(10, 29):47 => 70
# 點(11, 27):95 => 68
# 點(19, 31):99 => 69
# 點(21, 23):85 => 63
#
# 20211023_t055232.jpg
# 點(0, 15):89 => 67
# 點(0, 22):112 => 77
# 點(0, 28):81 => 54
# 點(1, 9):49 => 67
# 點(2, 30):121 => 92
# 點(4, 5):92 => 68
# 點(6, 9):48 => 76
# 點(6, 28):114 => 94
# 點(7, 14):110 => 79
# 點(8, 7):106 => 69
# 點(8, 10):119 => 71
# 點(9, 10):88 => 65
# 點(9, 27):129 => 93
# 點(10, 3):93 => 64
# 點(11, 17):89 => 62
# 點(11, 23):76 => 54
# 點(12, 6):84 => 54
# 點(13, 26):89 => 59
# 點(14, 12):85 => 61
# 點(19, 31):90 => 68
# 點(20, 30):98 => 71
# 點(23, 24):50 => 72
#
# 20211023_t055238.jpg
# 點(0, 30):89 => 65
# 點(1, 31):89 => 82
# 點(2, 6):78 => 58
# 點(2, 20):129 => 102
# 點(2, 31):122 => 111
# 點(4, 11):80 => 88
# 點(4, 15):117 => 88
# 點(4, 21):67 => 111
# 點(4, 22):135 => 108
# 點(4, 28):155 => 111
# 點(6, 2):81 => 60
# 點(6, 10):101 => 68
# 點(6, 15):114 => 86
# 點(7, 9):89 => 68
# 點(8, 4):84 => 59
# 點(8, 12):50 => 75
# 點(9, 5):82 => 54
# 點(9, 18):54 => 88
# 點(10, 4):104 => 64
# 點(10, 16):51 => 77
# 點(11, 17):53 => 81
# 點(14, 4):83 => 60
# 點(17, 14):85 => 65
# 點(17, 30):93 => 59
# 點(20, 11):77 => 51
# 點(21, 6):47 => 69
#
# 20211023_t055240.jpg
# 點(0, 18):68 => 96
# 點(0, 30):95 => 67
# 點(1, 8):102 => 63
# 點(1, 31):98 => 75
# 點(2, 30):100 => 97
# 點(3, 17):102 => 73
# 點(3, 27):118 => 78
# 點(3, 30):156 => 102
# 點(3, 31):124 => 93
# 點(5, 21):64 => 81
# 點(5, 29):60 => 102
# 點(7, 13):95 => 68
# 點(7, 31):114 => 94
# 點(8, 9):89 => 65
# 點(8, 21):99 => 65
# 點(10, 6):47 => 68
# 點(10, 16):52 => 78
# 點(10, 31):69 => 91
# 點(12, 24):47 => 72
# 點(12, 26):50 => 71
# 點(23, 31):55 => 73
#
# 20211023_t055242.jpg
# 點(0, 19):126 => 98
# 點(0, 28):49 => 71
# 點(3, 21):118 => 86
# 點(3, 30):153 => 112
# 點(4, 2):46 => 69
# 點(4, 18):59 => 83
# 點(6, 14):61 => 85
# 點(7, 30):69 => 105
# 點(8, 23):109 => 78
# 點(8, 25):68 => 92
# 點(9, 6):50 => 72
# 點(9, 17):100 => 69
# 點(9, 30):119 => 81
# 點(10, 24):62 => 84
# 點(11, 8):50 => 68
# 點(11, 30):101 => 73
# 點(12, 21):49 => 67
# 點(14, 27):93 => 63
# 點(18, 27):90 => 63
# 點(20, 2):47 => 66
# 點(20, 22):46 => 65
# 點(21, 16):47 => 68
# 點(23, 30):95 => 67
#
# 20211023_t055244.jpg
# 點(0, 0):51 => 69
# 點(0, 18):109 => 80
# 點(2, 26):105 => 78
# 點(2, 28):53 => 79
# 點(3, 29):114 => 90
# 點(4, 2):81 => 58
# 點(4, 23):68 => 86
# 點(4, 25):63 => 84
# 點(4, 29):72 => 109
# 點(4, 30):158 => 109
# 點(5, 11):89 => 68
# 點(5, 26):105 => 86
# 點(6, 28):108 => 83
# 點(7, 10):51 => 72
# 點(9, 15):91 => 63
# 點(11, 23):103 => 62
# 點(11, 28):46 => 68
# 點(11, 31):100 => 62
# 點(13, 13):49 => 68
# 點(16, 21):46 => 69
# 點(18, 10):46 => 68
# 點(19, 31):85 => 63
#
# 20211023_t055246.jpg
# 點(2, 18):65 => 93
# 點(3, 30):155 => 116
# 點(4, 17):115 => 83
# 點(5, 26):70 => 97
# 點(6, 30):53 => 94
# 點(8, 18):50 => 76
# 點(9, 10):91 => 62
# 點(11, 23):51 => 71
# 點(12, 19):94 => 52
# 點(20, 12):47 => 68
# 點(22, 21):81 => 59
#
# 20211023_t055248.jpg
# 點(0, 16):49 => 75
# 點(0, 30):64 => 86
# 點(3, 30):156 => 104
# 點(5, 14):58 => 81
# 點(5, 20):97 => 73
# 點(6, 19):91 => 65
# 點(7, 20):99 => 70
# 點(8, 16):50 => 81
# 點(10, 22):49 => 81
# 點(10, 31):93 => 70
# 點(11, 30):90 => 64
# 點(20, 31):96 => 56
# 點(22, 7):78 => 53
#
# 20211023_t055250.jpg
# 點(0, 28):105 => 59
# 點(1, 20):70 => 86
# 點(1, 21):50 => 83
# 點(2, 12):88 => 56
# 點(2, 18):65 => 94
# 點(3, 28):84 => 107
# 點(3, 30):150 => 115
# 點(4, 11):51 => 77
# 點(5, 14):108 => 71
# 點(6, 18):96 => 72
# 點(6, 28):118 => 80
# 點(7, 28):59 => 87
# 點(8, 22):50 => 81
# 點(9, 17):83 => 59
# 點(11, 31):100 => 68
# 點(12, 17):46 => 66
# 點(13, 8):48 => 67
# 點(13, 14):79 => 58
# 點(20, 26):74 => 53
# 點(23, 6):47 => 67
# 點(23, 16):50 => 68
#
# 20211023_t055252.jpg
# 點(0, 3):87 => 67
# 點(2, 18):68 => 95
# 點(2, 22):58 => 86
# 點(3, 26):107 => 78
# 點(3, 30):158 => 104
# 點(4, 23):110 => 82
# 點(4, 29):79 => 109
# 點(5, 15):63 => 92
# 點(5, 27):73 => 107
# 點(6, 21):103 => 75
# 點(6, 25):115 => 88
# 點(12, 15):87 => 62
# 點(13, 0):71 => 50
# 點(13, 14):82 => 58
# 點(19, 30):82 => 60
# 點(20, 27):85 => 58
# 點(20, 29):88 => 64
# 點(22, 16):49 => 73
#
# 20211023_t055254.jpg
# 點(0, 0):51 => 80
# 點(0, 3):86 => 60
# 點(0, 11):90 => 60
# 點(0, 20):62 => 106
# 點(0, 24):55 => 77
# 點(1, 26):55 => 75
# 點(2, 17):111 => 82
# 點(3, 12):91 => 66
# 點(3, 22):112 => 81
# 點(3, 24):112 => 79
# 點(3, 28):118 => 86
# 點(4, 27):114 => 92
# 點(5, 10):85 => 55
# 點(6, 5):82 => 55
# 點(6, 11):92 => 62
# 點(6, 26):74 => 95
# 點(7, 4):83 => 58
# 點(7, 17):58 => 84
# 點(7, 19):67 => 88
# 點(7, 21):53 => 94
# 點(7, 22):76 => 100
# 點(8, 7):98 => 67
# 點(8, 9):88 => 60
# 點(8, 12):51 => 85
# 點(9, 4):92 => 61
# 點(9, 8):83 => 60
# 點(9, 27):111 => 89
# 點(10, 3):94 => 61
# 點(10, 12):53 => 77
# 點(10, 28):51 => 80
# 點(11, 16):82 => 60
# 點(12, 15):88 => 64
# 點(14, 23):82 => 55
# 點(15, 31):58 => 77
# 點(17, 10):87 => 61
# 點(19, 27):95 => 65
# 點(20, 7):86 => 61
# 點(23, 24):89 => 63
#
# 20211023_t055256.jpg
# 點(0, 22):96 => 74
# 點(2, 0):53 => 70
# 點(2, 30):105 => 92
# 點(3, 30):156 => 108
# 點(5, 23):57 => 87
# 點(5, 31):107 => 101
# 點(6, 16):96 => 64
# 點(6, 25):64 => 95
# 點(7, 18):56 => 80
# 點(7, 28):110 => 80
# 點(7, 29):64 => 87
# 點(9, 16):89 => 66
# 點(10, 18):96 => 60
# 點(11, 0):97 => 65
# 點(13, 28):49 => 68
# 點(16, 7):48 => 70
# 點(19, 31):86 => 58
# 點(23, 27):85 => 59
# finish

# %% [markdown]
# ## find notice image

# %%
import cv2
import os


directory_name = r"D:\test3_error"
print("max pixel   min pixel   filename")
for filename in os.listdir(directory_name):
        
    img = cv2.imread(directory_name + "/" + filename,0)
    shape = img.shape
    ymax = shape[0]
    xmax = shape[1]

    l = []
    for i in range(ymax):   
        for j in range(xmax):
            now_pixel = int(img[i][j])
            l.append(now_pixel)
    
    print(f"{max(l)}         {min(l)}          {filename}")
# Out:
# max pixel   min pixel   filename
# 249         55          20211023_t054832.jpg
# 156         76          20211023_t054904.jpg
# 250         52          20211023_t055140.jpg
# 249         34          20211023_t060804.jpg
# 253         63          20211023_t061032.jpg
# 253         64          20211023_t061304.jpg
# 246         41          20211023_t061330.jpg
# 252         51          20211023_t061402.jpg
